# %%
import os
if 'COLAB_GPU' in os.environ:
  print("enable")
# Out:
# enable

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.8/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content/speedLimit/Self-Driving-Cars-6'

# %%
# !mkdir speedLimit

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  speedLimit  train  yolov8n.pt
# README.dataset.txt  runs		 test	     valid

# %%
os.chdir("/content/speedLimit")
# %pwd
# Out:
# '/content/speedLimit'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AAAFwc8P7LAitvvLMLV6")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
os.chdir("/content/speedLimit/Self-Driving-Cars-6")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16
# Out:
# New https://pypi.org/project/ultralytics/8.3.205 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls '/content/speedLimit/Self-Driving-Cars-6/runs/detect/train3/'
# Out:
# args.yaml			 labels.jpg		val_batch0_pred.jpg
# BoxF1_curve.png			 results.csv		val_batch1_labels.jpg
# BoxP_curve.png			 results.png		val_batch1_pred.jpg
# BoxPR_curve.png			 train_batch0.jpg	val_batch2_labels.jpg
# BoxR_curve.png			 train_batch1.jpg	val_batch2_pred.jpg
# confusion_matrix_normalized.png  train_batch2.jpg	weights
# confusion_matrix.png		 val_batch0_labels.jpg

# %%
resultD="/content/speedLimit/Self-Driving-Cars-6/runs/detect/train3/"
from IPython.display import Image, display
Image(filename=f'{resultD}confusion_matrix.png')

# %%
Image(filename=f'{resultD}results.png')

# %%
# %pwd
# Out:
# '/content/speedLimit/Self-Driving-Cars-6'

# %%
os.chdir("/content")
# %pwd
# Out:
# '/content'

# %%
# !mkdir manualtest

# %%
os.chdir("/content/manualtest")
# %pwd
# Out:
# '/content/manualtest'

# %%
url = "https://drive.google.com/file/d/1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v/view?usp=sharing"
id = '1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v' -O inputvideoforstopsign.mp4
# Out:
# --2025-10-05 14:31:30--  https://docs.google.com/uc?export=download&id=1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v
# Resolving docs.google.com (docs.google.com)... 142.250.107.138, 142.250.107.102, 142.250.107.139, ...
# Connecting to docs.google.com (docs.google.com)|142.250.107.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v&export=download [following]
# --2025-10-05 14:31:30--  https://drive.usercontent.google.com/download?id=1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.253.117.132, 2607:f8b0:400e:c0a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.253.117.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 624191 (610K) [video/mp4]
# Saving to: ‘inputvideoforstopsign.mp4’
#
# ...

# %%
url = "https://drive.google.com/file/d/1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v/view?usp=sharing"
id = '1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Kf5ujLGHUo5EGzJUNL3df3xfUbTe_y1v' -O inputvideoforstopsign.mp4

# %%
url = "https://drive.google.com/file/d/1M4v_QtXDtB8s6GLm3bcO0LV97IQXw-W4/view?usp=sharing"
id = '1M4v_QtXDtB8s6GLm3bcO0LV97IQXw-W4'

# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1M4v_QtXDtB8s6GLm3bcO0LV97IQXw-W4' -O VideoWithRedAndGreenLight.mp4
# Out:
# --2025-10-05 14:36:22--  https://docs.google.com/uc?export=download&id=1M4v_QtXDtB8s6GLm3bcO0LV97IQXw-W4
# Resolving docs.google.com (docs.google.com)... 142.250.99.102, 142.250.99.113, 142.250.99.139, ...
# Connecting to docs.google.com (docs.google.com)|142.250.99.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1M4v_QtXDtB8s6GLm3bcO0LV97IQXw-W4&export=download [following]
# --2025-10-05 14:36:22--  https://drive.usercontent.google.com/download?id=1M4v_QtXDtB8s6GLm3bcO0LV97IQXw-W4&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.253.117.132, 2607:f8b0:400e:c0a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.253.117.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 587846 (574K) [video/mp4]
# Saving to: ‘VideoWithRedAndGreenLight.mp4’
#
# ...

# %%
url = "https://drive.google.com/file/d/1eSt-K1AwHwlWuMJeeNwWQKi2nxm4cYDr/view?usp=sharing"


# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1eSt-K1AwHwlWuMJeeNwWQKi2nxm4cYDr' -O VideoWithRedAndGreenLightWithSpeedLimit.mp4
# Out:
# --2025-10-05 14:37:48--  https://docs.google.com/uc?export=download&id=1eSt-K1AwHwlWuMJeeNwWQKi2nxm4cYDr
# Resolving docs.google.com (docs.google.com)... 74.125.199.101, 74.125.199.100, 74.125.199.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.199.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eSt-K1AwHwlWuMJeeNwWQKi2nxm4cYDr&export=download [following]
# --2025-10-05 14:37:48--  https://drive.usercontent.google.com/download?id=1eSt-K1AwHwlWuMJeeNwWQKi2nxm4cYDr&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.135.132, 2607:f8b0:400e:c0a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.135.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1174035 (1.1M) [video/mp4]
# Saving to: ‘VideoWithRedAndGreenLightWithSpeedLimit.mp4’
#
# ...

# %%
paths ="/content/speedLimit/Self-Driving-Cars-6/runs/detect/train3/weights"
# !yolo task=detect mode=predict model={paths}/best.pt conf=.25 source='inputvideoforstopsign.mp4' save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 43.8ms
# video 1/1 (frame 2/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 6.3ms
# video 1/1 (frame 3/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 5.6ms
# video 1/1 (frame 4/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 5.7ms
# video 1/1 (frame 5/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 5.5ms
# video 1/1 (frame 6/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 5.5ms
# video 1/1 (frame 7/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 5.5ms
# video 1/1 (frame 8/150) /content/manualtest/inputvideoforstopsign.mp4: 384x640 1 Stop, 5.9ms
# ...

# %%
paths ="/content/speedLimit/Self-Driving-Cars-6/runs/detect/train3/weights"
# !yolo task=detect mode=predict model={paths}/best.pt conf=.25 source='VideoWithRedAndGreenLightWithSpeedLimit.mp4' save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/929) /content/manualtest/VideoWithRedAndGreenLightWithSpeedLimit.mp4: 384x640 1 Green Light, 2 Red Lights, 1 Speed Limit 50, 46.2ms
# video 1/1 (frame 2/929) /content/manualtest/VideoWithRedAndGreenLightWithSpeedLimit.mp4: 384x640 1 Green Light, 2 Red Lights, 1 Speed Limit 50, 5.9ms
# video 1/1 (frame 3/929) /content/manualtest/VideoWithRedAndGreenLightWithSpeedLimit.mp4: 384x640 1 Green Light, 2 Red Lights, 1 Speed Limit 50, 5.6ms
# video 1/1 (frame 4/929) /content/manualtest/VideoWithRedAndGreenLightWithSpeedLimit.mp4: 384x640 1 Green Light, 2 Red Lights, 1 Speed Limit 50, 5.6ms
# video 1/1 (frame 5/929) /content/manualtest/VideoWithRedAndGreenLightWithSpeedLimit.mp4: 384x640 1 Green Light, 2 Red Lights, 1 Speed Limit 50, 5.8ms
# ...

# %%
paths ="/content/speedLimit/Self-Driving-Cars-6/runs/detect/train3/weights"
# !yolo task=detect mode=predict model={paths}/best.pt conf=.25 source='VideoWithRedAndGreenLight.mp4' save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 1 Green Light, 2 Red Lights, 57.5ms
# video 1/1 (frame 2/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 1 Green Light, 2 Red Lights, 6.0ms
# video 1/1 (frame 3/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 1 Green Light, 2 Red Lights, 5.9ms
# video 1/1 (frame 4/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 1 Green Light, 2 Red Lights, 5.6ms
# video 1/1 (frame 5/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 2 Red Lights, 5.5ms
# video 1/1 (frame 6/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 2 Red Lights, 5.5ms
# video 1/1 (frame 7/494) /content/manualtest/VideoWithRedAndGreenLight.mp4: 384x640 1 Green Light, 2 Red Lights, 5.5ms
# ...
